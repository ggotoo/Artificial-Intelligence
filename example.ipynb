# %%
import pandas as pd
import os
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1ph9qcAk_hZsUnVWmDIBgs5NF-9iX4uP3/export?format=csv")

# %%
df.isnull().sum().sum() / df.size
# Out:
# 0.37307312208169

# %%
df.isnull().sum()/100
# Out:
# Unnamed: 0             0.00
# QKEY                   0.00
# INTERVIEW_START_W99    0.00
# INTERVIEW_END_W99      0.00
# DEVICE_TYPE_W99        0.00
#                        ...
# F_IDEO                 0.00
# F_INTFREQ              1.73
# F_VOLSUM               0.00
# F_INC_TIER2            0.00
# WEIGHT_W99             0.00
# Length: 215, dtype: float64

# %%
EXCITEOE = ["EXCITEOE_W99_OE1","EXCITEOE_W99_OE2","EXCITEOE_W99_OE3","EXCITEOE_REFUSED_W99"]
CONCERNOE = ["CONCERNOE_W99_OE1", "CONCERNOE_W99_OE2","CONCERNOE_W99_OE3", "CONCERNOE_REFUSED_W99"]
DISCRIM = ["DISCRIM1_a_W99","DISCRIM1_b_W99", "DISCRIM1_c_W99","DISCRIM1_d_W99", "DISCRIM1_e_W99","DISCRIM1_f_W99"]
POSNEGAI = ["POSNEGAI_a_W99","POSNEGAI_b_W99","POSNEGAI_c_W99","POSNEGAI_d_W99","POSNEGAI_e_W99","POSNEGAI_f_W99"]
POSNEGHE = ["POSNEGHE_a_W99","POSNEGHE_b_W99","POSNEGHE_c_W99","POSNEGHE_d_W99","POSNEGHE_e_W99","POSNEGHE_f_W99"]
SMAL_W99 = ["SMALG1_W99","SMALG2_W99","SMALG3_W99","SMALG4_a_W99","SMALG4_b_W99","SMALG4_c_W99","SMALG4_d_W99","SMALG5_W99","SMALG6_W99","SMALG7_W99","SMALG8_W99","SMALG9_a_W99","SMALG9_b_W99","SMALG9_c_W99","SMALG10_a_W99","SMALG10_b_W99","SMALG10_c_W99","SMALG11_W99","SMALG12_W99","SMALG13_a_W99","SMALG13_b_W99","SMALG13_c_W99","SMALG13_d_W99"]
FACERE =["FACEREC1_W99","FACEREC2_W99","FACEREC3_a_W99","FACEREC3_b_W99","FACEREC3_c_W99","FACEREC3_d_W99","FACEREC3_e_W99","FACEREC3_f_W99","FACEREC4_W99","FACEREC5_W99","FACEREC6_a_W99","FACEREC6_b_W99","FACEREC6_c_W99","FACEREC6_d_W99","FACEREC7_W99","FACEREC8_a_W99","FACEREC8_b_W99","FACEREC8_c_W99","FACEREC9_W99","FACEREC10_W99","FACEREC11_a_W99","FACEREC11_b_W99","FACEREC11_c_W99","FACEREC12_a_W99","FACEREC12_b_W99","FACEREC12_c_W99","FACEREC12_d_W99"]
DCARS = ['DCARS1_W99', 'DCARS2_W99', 'DCARS3_W99', 'DCARS4_a_W99', 'DCARS4_b_W99','DCARS4_c_W99', 'DCARS4_d_W99', 'DCARS5_W99', 'DCARS6_W99', 'DCARS7_W99','DCARS8_a_W99', 'DCARS8_b_W99', 'DCARS8_c_W99', 'DCARS8_d_W99', 'DCARS9_W99','DCARS10_W99', 'DCARS11_a_W99', 'DCARS11_b_W99', 'DCARS11_c_W99', 'DCARS11_d_W99','DCARS12_W99', 'DCARS13_a_W99', 'DCARS13_b_W99', 'DCARS13_c_W99', 'DCARS13_d_W99']
BCHIP = ["BCHIP1_W99","BCHIP2_W99","BCHIP3_W99","BCHIP4_a_W99","BCHIP4_b_W99","BCHIP4_c_W99","BCHIP4_d_W99","BCHIP5_W99","BCHIP6_W99","BCHIP7_W99","BCHIP8_W99","BCHIP9_a_W99","BCHIP9_b_W99","BCHIP9_c_W99","BCHIP10_a_W99","BCHIP10_b_W99","BCHIP10_c_W99","BCHIP10_d_W99","BCHIP11_W99","BCHIP12_W99","BCHIP13_a_W99","BCHIP13_b_W99","BCHIP14_a_W99","BCHIP14_b_W99","BCHIP14_c_W99","BCHIP14_d_W99"]
GENEV = ["GENEV1_W99","GENEV2_W99","GENEV3_W99","GENEV4_a_W99","GENEV4_b_W99","GENEV4_c_W99","GENEV4_d_W99","GENEV5_W99","GENEV6_W99","GENEV7_W99","GENEV8_W99","GENEV9_a_W99","GENEV9_b_W99","GENEV9_c_W99","GENEV9_d_W99","GENEV10_W99","GENEV11_W99","GENEV12_a_W99","GENEV12_b_W99","GENEV12_c_W99","GENEV13_a_W99","GENEV13_b_W99"]
EXO =["EXOV1_W99","EXOV2_W99","EXOV3_W99","EXOV4_a_W99","EXOV4_b_W99","EXOV4_c_W99","EXOV4_d_W99","EXOV5_W99","EXOV6_W99","EXOV6_W99","EXOV7_W99","EXOV8_a_W99","EXOV8_b_W99","EXOV8_c_W99","EXOV8_d_W99","EXOV9_W99","EXOV10_W99","EXOV11_a_W99","EXOV11_b_W99","EXOV12_a_W99","EXOV12_b_W99","EXOV12_c_W99"]
INTERVIEW_TIME = ["INTERVIEW_START_W99","INTERVIEW_END_W99"]

# %%
# Combine all column lists
columns_to_drop = POSNEGAI + POSNEGHE + SMAL_W99 + FACERE + BCHIP + GENEV + EXO+ INTERVIEW_TIME+EXCITEOE+CONCERNOE
# Drop the specified columns
df_dropped = df.drop(columns=columns_to_drop)

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9696 entries, 0 to 10259
# Data columns (total 74 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            9696 non-null   int64
#  1   QKEY                  9696 non-null   int64
#  2   DEVICE_TYPE_W99       9696 non-null   object
#  3   LANG_W99              9696 non-null   object
#  4   FORM_W99              9696 non-null   object
#  5   XTABLET_W99           9696 non-null   object
#  6   TECH1_W99             9696 non-null   object
#  7   SC1_W99               9696 non-null   object
#  8   CNCEXC_W99            9696 non-null   object
#  9   ALGFAIR_W99           9696 non-null   object
#  10  DISCRIM1_a_W99        9696 non-null   object
#  11  DISCRIM1_b_W99        9696 non-null   object
#  12  DISCRIM1_c_W99        9696 non-null   object
#  13  DISCRIM1_d_W99        9696 non-null   object
#  14  DISCRIM1_e_W99        9696 non-null   object
#  15  DISCRIM1_f_W99        9696 non-null   object
#  16  DCARS1_W99            9696 non-null   object
#  17  DCARS2_W99            9696 non-null   object
#  18  DCARS3_W99            9696 non-null   object
#  19  DCARS4_a_W99          9696 non-null   object
#  20  DCARS4_b_W99          9696 non-null   object
#  21  DCARS4_c_W99          9696 non-null   object
#  22  DCARS4_d_W99          9696 non-null   object
#  23  DCARS5_W99            9696 non-null   object
#  24  DCARS6_W99            9696 non-null   object
#  25  DCARS7_W99            9696 non-null   object
#  26  DCARS8_a_W99          9696 non-null   object
#  27  DCARS8_b_W99          9696 non-null   object
#  28  DCARS8_c_W99          9696 non-null   object
#  29  DCARS8_d_W99          9696 non-null   object
#  30  DCARS9_W99            9696 non-null   object
#  31  DCARS10_W99           9696 non-null   object
#  32  DCARS11_a_W99         9696 non-null   object
#  33  DCARS11_b_W99         9696 non-null   object
#  34  DCARS11_c_W99         9696 non-null   object
#  35  DCARS11_d_W99         9696 non-null   object
#  36  DCARS12_W99           9696 non-null   object
#  37  DCARS13_a_W99         9696 non-null   object
#  38  DCARS13_b_W99         9696 non-null   object
#  39  DCARS13_c_W99         9696 non-null   object
#  40  DCARS13_d_W99         9696 non-null   object
#  41  F_RELCOM3CAT          9696 non-null   object
#  42  F_METRO               9696 non-null   object
#  43  F_CREGION             9696 non-null   object
#  44  F_CDIVISION           9696 non-null   object
#  45  F_AGECAT              9696 non-null   object
#  46  F_GENDER              9696 non-null   object
#  47  F_EDUCCAT             9696 non-null   object
#  48  F_EDUCCAT2            9696 non-null   object
#  49  F_HISP                9696 non-null   object
#  50  F_HISP_ORIGIN         1186 non-null   object
#  51  F_YEARSINUS           9696 non-null   object
#  52  F_RACECMB             9696 non-null   object
#  53  F_RACETHNMOD          9696 non-null   object
#  54  F_CITIZEN             9696 non-null   object
#  55  F_BIRTHPLACE          9696 non-null   object
#  56  F_MARITAL             9696 non-null   object
#  57  F_RELIG               9696 non-null   object
#  58  F_BORN                6488 non-null   object
#  59  F_RELIGCAT1           9696 non-null   object
#  60  F_ATTEND              9696 non-null   object
#  61  F_RELIMP              9696 non-null   object
#  62  F_PRAY                9696 non-null   object
#  63  F_PARTY_FINAL         9696 non-null   object
#  64  F_PARTYLN_FINAL       3501 non-null   object
#  65  F_PARTYSUM_FINAL      9696 non-null   object
#  66  F_PARTYSUMIDEO_FINAL  9696 non-null   object
#  67  F_INC_SDT1            9696 non-null   object
#  68  F_REG                 9696 non-null   object
#  69  F_IDEO                9696 non-null   object
#  70  F_INTFREQ             9696 non-null   object
#  71  F_VOLSUM              9696 non-null   object
#  72  F_INC_TIER2           9696 non-null   object
#  73  WEIGHT_W99            9696 non-null   float64
# dtypes: float64(1), int64(2), object(71)
# memory usage: 5.5+ MB

# %%
df_dropped.head()
# Out:
#    Unnamed: 0    QKEY DEVICE_TYPE_W99 LANG_W99 FORM_W99    XTABLET_W99  \
# 0           0  100260       Laptop/PC  English   Form 2  Non-tablet HH
# 1           1  100314      Smartphone  English   Form 1  Non-tablet HH
# 2           2  100363      Smartphone  English   Form 1  Non-tablet HH
# 3           3  100598       Laptop/PC  English   Form 2  Non-tablet HH
# 4           4  100637       Laptop/PC  English   Form 2  Non-tablet HH
#
#          TECH1_W99                              SC1_W99  \
# 0  Mostly positive                      Mostly positive
# 1  Mostly positive                      Mostly positive
# 2  Mostly positive                      Mostly positive
# 3  Mostly positive                      Mostly positive
# 4  Mostly positive  Equal positive and negative effects
#
#                       CNCEXC_W99   ALGFAIR_W99  ...       F_PARTYLN_FINAL  \
# 0  Equally concerned and excited  Not possible  ...                   NaN
# 1    More excited than concerned      Possible  ...                   NaN
# 2  Equally concerned and excited  Not possible  ...                   NaN
# 3  Equally concerned and excited  Not possible  ...                   NaN
# 4  Equally concerned and excited      Not sure  ...  The Republican Party
#
#   F_PARTYSUM_FINAL            F_PARTYSUMIDEO_FINAL  \
# 0     Rep/Lean Rep           Conservative Rep/Lean
# 1     Rep/Lean Rep       Moderate/Liberal Rep/Lean
# 2     Dem/Lean Dem  Moderate/Conservative Dem/Lean
# 3     Rep/Lean Rep           Conservative Rep/Lean
# 4     Rep/Lean Rep           Conservative Rep/Lean
#
#                      F_INC_SDT1  \
# 0  $50,000 to less than $60,000
# 1  $40,000 to less than $50,000
# 2              $100,000 or more
# 3              $100,000 or more
# 4  $30,000 to less than $40,000
#
#                                                F_REG             F_IDEO  \
# 0  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
#
#              F_INTFREQ F_VOLSUM    F_INC_TIER2 WEIGHT_W99
# 0  Several times a day       No  Middle income   0.206396
# 1  Several times a day      Yes  Middle income   0.315090
# 2  Several times a day       No   Upper income   0.829579
# 3  Several times a day      Yes   Upper income   0.337527
# 4           Less often       No   Lower income   1.210606
#
# [5 rows x 74 columns]

# %%
df_dropped = df_dropped.drop(columns=["Unnamed: 0","QKEY","DEVICE_TYPE_W99","FORM_W99","XTABLET_W99","F_PARTYLN_FINAL","F_PARTYSUM_FINAL","F_PARTYSUMIDEO_FINAL","F_RELIG","F_BORN","F_ATTEND","F_RELIMP","F_PRAY","F_INC_SDT1","F_IDEO","F_INTFREQ","F_VOLSUM","F_RACECMB","F_HISP","F_HISP_ORIGIN","F_EDUCCAT","F_YEARSINUS","LANG_W99","F_BIRTHPLACE","F_RELCOM3CAT","F_CREGION","F_REG"])

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9696 entries, 0 to 10259
# Data columns (total 47 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TECH1_W99       9696 non-null   object
#  1   SC1_W99         9696 non-null   object
#  2   CNCEXC_W99      9696 non-null   object
#  3   ALGFAIR_W99     9696 non-null   object
#  4   DISCRIM1_a_W99  9696 non-null   object
#  5   DISCRIM1_b_W99  9696 non-null   object
#  6   DISCRIM1_c_W99  9696 non-null   object
#  7   DISCRIM1_d_W99  9696 non-null   object
#  8   DISCRIM1_e_W99  9696 non-null   object
#  9   DISCRIM1_f_W99  9696 non-null   object
#  10  DCARS1_W99      9696 non-null   object
#  11  DCARS2_W99      9696 non-null   object
#  12  DCARS3_W99      9696 non-null   object
#  13  DCARS4_a_W99    9696 non-null   object
#  14  DCARS4_b_W99    9696 non-null   object
#  15  DCARS4_c_W99    9696 non-null   object
#  16  DCARS4_d_W99    9696 non-null   object
#  17  DCARS5_W99      9696 non-null   object
#  18  DCARS6_W99      9696 non-null   object
#  19  DCARS7_W99      9696 non-null   object
#  20  DCARS8_a_W99    9696 non-null   object
#  21  DCARS8_b_W99    9696 non-null   object
#  22  DCARS8_c_W99    9696 non-null   object
#  23  DCARS8_d_W99    9696 non-null   object
#  24  DCARS9_W99      9696 non-null   object
#  25  DCARS10_W99     9696 non-null   object
#  26  DCARS11_a_W99   9696 non-null   object
#  27  DCARS11_b_W99   9696 non-null   object
#  28  DCARS11_c_W99   9696 non-null   object
#  29  DCARS11_d_W99   9696 non-null   object
#  30  DCARS12_W99     9696 non-null   object
#  31  DCARS13_a_W99   9696 non-null   object
#  32  DCARS13_b_W99   9696 non-null   object
#  33  DCARS13_c_W99   9696 non-null   object
#  34  DCARS13_d_W99   9696 non-null   object
#  35  F_METRO         9696 non-null   object
#  36  F_CDIVISION     9696 non-null   object
#  37  F_AGECAT        9696 non-null   object
#  38  F_GENDER        9696 non-null   object
#  39  F_EDUCCAT2      9696 non-null   object
#  40  F_RACETHNMOD    9696 non-null   object
#  41  F_CITIZEN       9696 non-null   object
#  42  F_MARITAL       9696 non-null   object
#  43  F_RELIGCAT1     9696 non-null   object
#  44  F_PARTY_FINAL   9696 non-null   object
#  45  F_INC_TIER2     9696 non-null   object
#  46  WEIGHT_W99      9696 non-null   float64
# dtypes: float64(1), object(46)
# memory usage: 3.6+ MB

# %%
#Check to see if there are any missing values
df_dropped.isnull().sum()/100
# Out:
# TECH1_W99         0.0
# SC1_W99           0.0
# CNCEXC_W99        0.0
# ALGFAIR_W99       0.0
# DISCRIM1_a_W99    0.0
# DISCRIM1_b_W99    0.0
# DISCRIM1_c_W99    0.0
# DISCRIM1_d_W99    0.0
# DISCRIM1_e_W99    0.0
# DISCRIM1_f_W99    0.0
# DCARS1_W99        0.0
# DCARS2_W99        0.0
# DCARS3_W99        0.0
# DCARS4_a_W99      0.0
# DCARS4_b_W99      0.0
# DCARS4_c_W99      0.0
# DCARS4_d_W99      0.0
# DCARS5_W99        0.0
# DCARS6_W99        0.0
# DCARS7_W99        0.0
# DCARS8_a_W99      0.0
# DCARS8_b_W99      0.0
# DCARS8_c_W99      0.0
# DCARS8_d_W99      0.0
# DCARS9_W99        0.0
# DCARS10_W99       0.0
# DCARS11_a_W99     0.0
# DCARS11_b_W99     0.0
# DCARS11_c_W99     0.0
# DCARS11_d_W99     0.0
# DCARS12_W99       0.0
# DCARS13_a_W99     0.0
# DCARS13_b_W99     0.0
# DCARS13_c_W99     0.0
# DCARS13_d_W99     0.0
# F_METRO           0.0
# F_CDIVISION       0.0
# F_AGECAT          0.0
# F_GENDER          0.0
# F_EDUCCAT2        0.0
# F_RACETHNMOD      0.0
# F_CITIZEN         0.0
# F_MARITAL         0.0
# F_RELIGCAT1       0.0
# F_PARTY_FINAL     0.0
# F_INC_TIER2       0.0
# WEIGHT_W99        0.0
# dtype: float64

# %%
threshold = len(df_dropped) * 0.05
threshold
# Out:
# 484.8

# %%
cols_to_drop = df_dropped.columns[df_dropped.isna().sum() <= threshold]
cols_to_drop
# Out:
# Index(['TECH1_W99', 'SC1_W99', 'CNCEXC_W99', 'ALGFAIR_W99', 'DISCRIM1_a_W99',
#        'DISCRIM1_b_W99', 'DISCRIM1_c_W99', 'DISCRIM1_d_W99', 'DISCRIM1_e_W99',
#        'DISCRIM1_f_W99', 'DCARS1_W99', 'DCARS2_W99', 'DCARS3_W99',
#        'DCARS4_a_W99', 'DCARS4_b_W99', 'DCARS4_c_W99', 'DCARS4_d_W99',
#        'DCARS5_W99', 'DCARS6_W99', 'DCARS7_W99', 'DCARS8_a_W99',
#        'DCARS8_b_W99', 'DCARS8_c_W99', 'DCARS8_d_W99', 'DCARS9_W99',
#        'DCARS10_W99', 'DCARS11_a_W99', 'DCARS11_b_W99', 'DCARS11_c_W99',
#        'DCARS11_d_W99', 'DCARS12_W99', 'DCARS13_a_W99', 'DCARS13_b_W99',
#        'DCARS13_c_W99', 'DCARS13_d_W99', 'F_METRO', 'F_CDIVISION', 'F_AGECAT',
#        'F_GENDER', 'F_EDUCCAT2', 'F_RACETHNMOD', 'F_CITIZEN', 'F_MARITAL',
#        'F_RELIGCAT1', 'F_PARTY_FINAL', 'F_INC_TIER2', 'WEIGHT_W99'],
#       dtype='object')

# %%
df_dropped.dropna(subset=cols_to_drop, inplace=True)

# %%
cols_with_missing_values = df_dropped.columns[df_dropped.isna().sum() > 0]
cols_with_missing_values
# Out:
# Index([], dtype='object')

# %%
df_dropped.isna().sum()/100
# Out:
# TECH1_W99         0.0
# SC1_W99           0.0
# CNCEXC_W99        0.0
# ALGFAIR_W99       0.0
# DISCRIM1_a_W99    0.0
# DISCRIM1_b_W99    0.0
# DISCRIM1_c_W99    0.0
# DISCRIM1_d_W99    0.0
# DISCRIM1_e_W99    0.0
# DISCRIM1_f_W99    0.0
# DCARS1_W99        0.0
# DCARS2_W99        0.0
# DCARS3_W99        0.0
# DCARS4_a_W99      0.0
# DCARS4_b_W99      0.0
# DCARS4_c_W99      0.0
# DCARS4_d_W99      0.0
# DCARS5_W99        0.0
# DCARS6_W99        0.0
# DCARS7_W99        0.0
# DCARS8_a_W99      0.0
# DCARS8_b_W99      0.0
# DCARS8_c_W99      0.0
# DCARS8_d_W99      0.0
# DCARS9_W99        0.0
# DCARS10_W99       0.0
# DCARS11_a_W99     0.0
# DCARS11_b_W99     0.0
# DCARS11_c_W99     0.0
# DCARS11_d_W99     0.0
# DCARS12_W99       0.0
# DCARS13_a_W99     0.0
# DCARS13_b_W99     0.0
# DCARS13_c_W99     0.0
# DCARS13_d_W99     0.0
# F_METRO           0.0
# F_CDIVISION       0.0
# F_AGECAT          0.0
# F_GENDER          0.0
# F_EDUCCAT2        0.0
# F_RACETHNMOD      0.0
# F_CITIZEN         0.0
# F_MARITAL         0.0
# F_RELIGCAT1       0.0
# F_PARTY_FINAL     0.0
# F_INC_TIER2       0.0
# WEIGHT_W99        0.0
# dtype: float64

# %%
imputer = SimpleImputer (strategy='most_frequent')
imputer.fit_transform(df_dropped)
# Out:
# array([['Mostly positive', 'Mostly positive',
#         'Equally concerned and excited', ..., 'Republican',
#         'Middle income', 0.2063963769],
#        ['Mostly positive', 'Mostly positive',
#         'More excited than concerned', ..., 'Republican',
#         'Middle income', 0.3150902898],
#        ['Mostly positive', 'Mostly positive',
#         'Equally concerned and excited', ..., 'Democrat', 'Upper income',
#         0.8295790779],
#        ...,
#        ['Mostly positive', 'Mostly positive',
#         'More concerned than excited', ..., 'Independent',
#         'Lower income', 0.2820789305],
#        ['Mostly positive', 'Mostly positive',
#         'More excited than concerned', ..., 'Republican',
#         'Middle income', 0.4415245381],
#        ['Mostly positive', 'Mostly positive',
#         'More excited than concerned', ..., 'Independent',
#         'Upper income', 0.90866993]], dtype=object)

# %%
columns_to_impute = [
    'TECH1_W99','SC1_W99','DCARS1_W99', 'DCARS2_W99', 'DCARS3_W99', 'DCARS4_a_W99', 'DCARS4_b_W99',
    'DCARS4_c_W99', 'DCARS4_d_W99', 'DCARS5_W99', 'DCARS6_W99', 'DCARS7_W99',
    'DCARS8_a_W99', 'DCARS8_b_W99', 'DCARS8_c_W99', 'DCARS8_d_W99', 'DCARS9_W99',
    'DCARS10_W99', 'DCARS11_a_W99', 'DCARS11_b_W99', 'DCARS11_c_W99', 'DCARS11_d_W99',
    'DCARS12_W99', 'DCARS13_a_W99', 'DCARS13_b_W99', 'DCARS13_c_W99', 'DCARS13_d_W99'
]

# Initialize the SimpleImputer with the mean strategy
imputer = SimpleImputer(strategy='most_frequent')

# Apply the imputer to the specified columns
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

# Save the cleaned dataset
df.to_csv('https://docs.google.com/spreadsheets/d/1ph9qcAk_hZsUnVWmDIBgs5NF-9iX4uP3/export?format=csv', index=False)

# Optional: Display the first few rows of the updated dataframe
df.head()
# Out:
#    Unnamed: 0    QKEY  INTERVIEW_START_W99    INTERVIEW_END_W99  \
# 0           0  100260  2021-11-03 14:25:27  2021-11-03 14:45:34
# 1           1  100314  2021-11-04 12:35:35  2021-11-04 12:55:29
# 2           2  100363  2021-11-03 20:23:43  2021-11-03 20:36:24
# 3           3  100598  2021-11-02 13:01:05  2021-11-04 12:37:42
# 4           4  100637  2021-11-02 12:32:58  2021-11-02 12:46:23
#
#   DEVICE_TYPE_W99 LANG_W99 FORM_W99    XTABLET_W99        TECH1_W99  \
# 0       Laptop/PC  English   Form 2  Non-tablet HH  Mostly positive
# 1      Smartphone  English   Form 1  Non-tablet HH  Mostly positive
# 2      Smartphone  English   Form 1  Non-tablet HH  Mostly positive
# 3       Laptop/PC  English   Form 2  Non-tablet HH  Mostly positive
# 4       Laptop/PC  English   Form 2  Non-tablet HH  Mostly positive
#
#                                SC1_W99  ...       F_PARTYLN_FINAL  \
# 0                      Mostly positive  ...                   NaN
# 1                      Mostly positive  ...                   NaN
# 2                      Mostly positive  ...                   NaN
# 3                      Mostly positive  ...                   NaN
# 4  Equal positive and negative effects  ...  The Republican Party
#
#   F_PARTYSUM_FINAL            F_PARTYSUMIDEO_FINAL  \
# 0     Rep/Lean Rep           Conservative Rep/Lean
# 1     Rep/Lean Rep       Moderate/Liberal Rep/Lean
# 2     Dem/Lean Dem  Moderate/Conservative Dem/Lean
# 3     Rep/Lean Rep           Conservative Rep/Lean
# 4     Rep/Lean Rep           Conservative Rep/Lean
#
#                      F_INC_SDT1  \
# 0  $50,000 to less than $60,000
# 1  $40,000 to less than $50,000
# 2              $100,000 or more
# 3              $100,000 or more
# 4  $30,000 to less than $40,000
#
#                                                F_REG             F_IDEO  \
# 0  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
#
#              F_INTFREQ F_VOLSUM    F_INC_TIER2 WEIGHT_W99
# 0  Several times a day       No  Middle income   0.206396
# 1  Several times a day      Yes  Middle income   0.315090
# 2  Several times a day       No   Upper income   0.829579
# 3  Several times a day      Yes   Upper income   0.337527
# 4           Less often       No   Lower income   1.210606
#
# [5 rows x 215 columns]

# %%
df.isna().sum()/100
# Out:
# Unnamed: 0             0.0
# QKEY                   0.0
# INTERVIEW_START_W99    0.0
# INTERVIEW_END_W99      0.0
# DEVICE_TYPE_W99        0.0
#                       ...
# F_IDEO                 0.0
# F_INTFREQ              0.0
# F_VOLSUM               0.0
# F_INC_TIER2            0.0
# WEIGHT_W99             0.0
# Length: 215, dtype: float64

# %%
df.isnull().sum().sum() / df.size
# Out:
# 0.310416186967534

# %%
df_dropped.isna().sum()/100
# Out:
# TECH1_W99         0.0
# SC1_W99           0.0
# CNCEXC_W99        0.0
# ALGFAIR_W99       0.0
# DISCRIM1_a_W99    0.0
# DISCRIM1_b_W99    0.0
# DISCRIM1_c_W99    0.0
# DISCRIM1_d_W99    0.0
# DISCRIM1_e_W99    0.0
# DISCRIM1_f_W99    0.0
# DCARS1_W99        0.0
# DCARS2_W99        0.0
# DCARS3_W99        0.0
# DCARS4_a_W99      0.0
# DCARS4_b_W99      0.0
# DCARS4_c_W99      0.0
# DCARS4_d_W99      0.0
# DCARS5_W99        0.0
# DCARS6_W99        0.0
# DCARS7_W99        0.0
# DCARS8_a_W99      0.0
# DCARS8_b_W99      0.0
# DCARS8_c_W99      0.0
# DCARS8_d_W99      0.0
# DCARS9_W99        0.0
# DCARS10_W99       0.0
# DCARS11_a_W99     0.0
# DCARS11_b_W99     0.0
# DCARS11_c_W99     0.0
# DCARS11_d_W99     0.0
# DCARS12_W99       0.0
# DCARS13_a_W99     0.0
# DCARS13_b_W99     0.0
# DCARS13_c_W99     0.0
# DCARS13_d_W99     0.0
# F_METRO           0.0
# F_CDIVISION       0.0
# F_AGECAT          0.0
# F_GENDER          0.0
# F_EDUCCAT2        0.0
# F_RACETHNMOD      0.0
# F_CITIZEN         0.0
# F_MARITAL         0.0
# F_RELIGCAT1       0.0
# F_PARTY_FINAL     0.0
# F_INC_TIER2       0.0
# WEIGHT_W99        0.0
# dtype: float64

# %%
#SHOW unique values in F_GENDER_W99
print(df_dropped['F_GENDER'].unique())
# Out:
# ['A man' 'A woman' 'In some other way' 'Refused']

# %%
# Define the value to be replaced and the new value
other_value = ['In some other way']

# Replace the values in the 'F_GENDER' column
df_dropped['F_GENDER'] = df_dropped['F_GENDER'].replace(other_value, 'Other')

# %%
sns.boxplot(df_dropped['F_AGECAT'].unique())
# Out:
# <Axes: >

# %%
# List of categorical variables
categorical_vars = ['TECH1_W99','SC1_W99',	'CNCEXC_W99',	'ALGFAIR_W99',	'DISCRIM1_a_W99',	'DISCRIM1_b_W99',	'DISCRIM1_c_W99',	'DISCRIM1_d_W99',	'DISCRIM1_e_W99',	'DISCRIM1_f_W99',	'F_AGECAT',	'F_GENDER',	'F_EDUCCAT2',	'F_RACETHNMOD',	'F_CITIZEN',	'DCARS1_W99',	'DCARS2_W99',	'DCARS3_W99',	'DCARS4_a_W99',	'DCARS4_b_W99',	'DCARS4_c_W99',	'DCARS4_d_W99',	'DCARS5_W99',	'DCARS6_W99',	'DCARS7_W99',	'DCARS8_a_W99',	'DCARS8_b_W99',	'DCARS8_c_W99',	'DCARS8_d_W99',	'DCARS9_W99',	'DCARS10_W99',	'DCARS11_a_W99',	'DCARS11_b_W99',	'DCARS11_c_W99',	'DCARS11_d_W99',	'DCARS12_W99',	'DCARS13_a_W99',	'DCARS13_b_W99',	'DCARS13_c_W99',	'DCARS13_d_W99',	'F_METRO','F_CDIVISION', 'F_MARITAL',	'F_RELIGCAT1',	'F_PARTY_FINAL',	'F_INC_TIER2']

#display the data types of the categorical variables
print(df_dropped[categorical_vars].dtypes)
# Out:
# TECH1_W99         object
# SC1_W99           object
# CNCEXC_W99        object
# ALGFAIR_W99       object
# DISCRIM1_a_W99    object
# DISCRIM1_b_W99    object
# DISCRIM1_c_W99    object
# DISCRIM1_d_W99    object
# DISCRIM1_e_W99    object
# DISCRIM1_f_W99    object
# F_AGECAT          object
# F_GENDER          object
# F_EDUCCAT2        object
# F_RACETHNMOD      object
# F_CITIZEN         object
# DCARS1_W99        object
# DCARS2_W99        object
# DCARS3_W99        object
# DCARS4_a_W99      object
# DCARS4_b_W99      object
# DCARS4_c_W99      object
# DCARS4_d_W99      object
# DCARS5_W99        object
# DCARS6_W99        object
# DCARS7_W99        object
# DCARS8_a_W99      object
# DCARS8_b_W99      object
# DCARS8_c_W99      object
# DCARS8_d_W99      object
# DCARS9_W99        object
# DCARS10_W99       object
# DCARS11_a_W99     object
# DCARS11_b_W99     object
# DCARS11_c_W99     object
# DCARS11_d_W99     object
# DCARS12_W99       object
# DCARS13_a_W99     object
# DCARS13_b_W99     object
# DCARS13_c_W99     object
# DCARS13_d_W99     object
# F_METRO           object
# F_CDIVISION       object
# F_MARITAL         object
# F_RELIGCAT1       object
# F_PARTY_FINAL     object
# F_INC_TIER2       object
# dtype: object

# %%
# Define the categorization function with corrections
def categorize_CARS(response):
    response = str(response).strip().lower()
    high_responses = ['a lot', 'definitely want', 'definitely would happen', 'very well', 'very comfortable', 'very positive', 'extremely comfortable', 'more acceptable', 'a major role']
    medium_responses = ['somewhat well', 'probably want', 'probably would happen', 'somewhat comfortable', 'probably not want', 'mostly positive', 'less acceptable', 'a minor role', 'a little', 'not too comfortable']
    low_responses = ['no difference', 'nothing at all', 'definitely not want', 'definitely would not happen', 'not too well', 'probably would not happen', 'not at all well', 'not comfortable at all', 'mostly negative', 'very negative', 'no difference', 'no role at all']
    uncertain_responses = ['not sure', 'don\'t know', 'no answer']

    if response in high_responses:
        return 'High'
    elif response in medium_responses:
        return 'Medium'
    elif response in low_responses:
        return 'Low'
    elif response in uncertain_responses:
        return 'Uncertain'
    else:
        return 'Unknown'

# List of columns to categorize
dcars_columns = ['DCARS1_W99', 'DCARS12_W99', 'DCARS11_a_W99',	'DCARS11_b_W99','DCARS11_c_W99',	'DCARS11_d_W99', 'DCARS8_a_W99',	'DCARS8_b_W99',	'DCARS8_c_W99',	'DCARS8_d_W99', 'DCARS4_a_W99',	'DCARS4_b_W99',	'DCARS4_c_W99',	'DCARS4_d_W99', 'DCARS3_W99']

# Check if the columns exist in the DataFrame before applying the function
existing_columns = [col for col in dcars_columns if col in df_dropped.columns]

# Apply the categorization function only to existing columns
df_dropped[existing_columns] = df_dropped[existing_columns].applymap(categorize_CARS)

# Display the first few rows to verify
print(df_dropped.head())
# Out:
#          TECH1_W99                              SC1_W99  \
# 0  Mostly positive                      Mostly positive
# 1  Mostly positive                      Mostly positive
# 2  Mostly positive                      Mostly positive
# 3  Mostly positive                      Mostly positive
# 4  Mostly positive  Equal positive and negative effects
#
#                       CNCEXC_W99   ALGFAIR_W99 DISCRIM1_a_W99 DISCRIM1_b_W99  \
# 0  Equally concerned and excited  Not possible   Not too well      Very well
# 1    More excited than concerned      Possible      Very well   Not too well
# 2  Equally concerned and excited  Not possible  Somewhat well  Somewhat well
# 3  Equally concerned and excited  Not possible       Not sure       Not sure
# 4  Equally concerned and excited      Not sure       Not sure       Not sure
#
#   DISCRIM1_c_W99 DISCRIM1_d_W99 DISCRIM1_e_W99 DISCRIM1_f_W99  ... F_AGECAT  \
# 0      Very well      Very well       Not sure       Not sure  ...      65+
# 1   Not too well       Not sure  Somewhat well      Very well  ...      65+
# 2  Somewhat well  Somewhat well      Very well  Somewhat well  ...    30-49
# 3       Not sure       Not sure       Not sure       Not sure  ...    50-64
# 4       Not sure       Not sure      Very well       Not sure  ...      65+
#
#   F_GENDER                       F_EDUCCAT2        F_RACETHNMOD F_CITIZEN  \
# 0    A man  College graduate/some post grad  White non-Hispanic       Yes
# 1    A man          Some college, no degree  White non-Hispanic       Yes
# 2  A woman                     Postgraduate  White non-Hispanic       Yes
# 3  A woman                     Postgraduate  White non-Hispanic       Yes
# 4  A woman               Associate's degree  White non-Hispanic       Yes
#
#             F_MARITAL   F_RELIGCAT1 F_PARTY_FINAL    F_INC_TIER2 WEIGHT_W99
# 0  Never been married  Unaffiliated    Republican  Middle income   0.206396
# 1            Divorced    Protestant    Republican  Middle income   0.315090
# 2             Married      Catholic      Democrat   Upper income   0.829579
# 3             Married    Protestant    Republican   Upper income   0.337527
# 4             Married    Protestant   Independent   Lower income   1.210606
#
# [5 rows x 47 columns]
# /var/folders/95/mkx4bvf95x35657hmtzpc5fr0000gn/T/ipykernel_21998/2522239481.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_dropped[existing_columns] = df_dropped[existing_columns].applymap(categorize_CARS)

# %%
df_dropped.head()
# Out:
#          TECH1_W99                              SC1_W99  \
# 0  Mostly positive                      Mostly positive
# 1  Mostly positive                      Mostly positive
# 2  Mostly positive                      Mostly positive
# 3  Mostly positive                      Mostly positive
# 4  Mostly positive  Equal positive and negative effects
#
#                       CNCEXC_W99   ALGFAIR_W99 DISCRIM1_a_W99 DISCRIM1_b_W99  \
# 0  Equally concerned and excited  Not possible   Not too well      Very well
# 1    More excited than concerned      Possible      Very well   Not too well
# 2  Equally concerned and excited  Not possible  Somewhat well  Somewhat well
# 3  Equally concerned and excited  Not possible       Not sure       Not sure
# 4  Equally concerned and excited      Not sure       Not sure       Not sure
#
#   DISCRIM1_c_W99 DISCRIM1_d_W99 DISCRIM1_e_W99 DISCRIM1_f_W99  ... F_AGECAT  \
# 0      Very well      Very well       Not sure       Not sure  ...      65+
# 1   Not too well       Not sure  Somewhat well      Very well  ...      65+
# 2  Somewhat well  Somewhat well      Very well  Somewhat well  ...    30-49
# 3       Not sure       Not sure       Not sure       Not sure  ...    50-64
# 4       Not sure       Not sure      Very well       Not sure  ...      65+
#
#   F_GENDER                       F_EDUCCAT2        F_RACETHNMOD F_CITIZEN  \
# 0    A man  College graduate/some post grad  White non-Hispanic       Yes
# 1    A man          Some college, no degree  White non-Hispanic       Yes
# 2  A woman                     Postgraduate  White non-Hispanic       Yes
# 3  A woman                     Postgraduate  White non-Hispanic       Yes
# 4  A woman               Associate's degree  White non-Hispanic       Yes
#
#             F_MARITAL   F_RELIGCAT1 F_PARTY_FINAL    F_INC_TIER2 WEIGHT_W99
# 0  Never been married  Unaffiliated    Republican  Middle income   0.206396
# 1            Divorced    Protestant    Republican  Middle income   0.315090
# 2             Married      Catholic      Democrat   Upper income   0.829579
# 3             Married    Protestant    Republican   Upper income   0.337527
# 4             Married    Protestant   Independent   Lower income   1.210606
#
# [5 rows x 47 columns]

# %%
df_dropped['DCARS12_W99'].unique()
# Out:
# array(['Medium', 'High', 'Low', 'Unknown'], dtype=object)

# %%
# Convert all values in the categorical columns to strings
#for column in categorical_vars:
#    df_dropped[column] = df_dropped[column].astype(str)

# Create a mapping dictionary dynamically
#mapping_dict = {}
#for column in categorical_vars:
#    unique_values = sorted(df_dropped[column].unique())
#    mapping_dict[column] = {value: idx + 1 for idx, value in enumerate(unique_values)}

# Define a function to map and convert columns
#def map_and_convert(df, column, mapping):
#    df_dropped[column] = df_dropped[column].map(mapping)
#    df_dropped[column] = pd.to_numeric(df[column])

# Loop through the categorical variables and apply the mapping
#for column in categorical_vars:
#    map_and_convert(df_dropped, column, mapping_dict[column])

# Save the new dataset with the encoded columns
#df_dropped.to_csv('https://docs.google.com/spreadsheets/d/1ph9qcAk_hZsUnVWmDIBgs5NF-9iX4uP3/export?format=csv', index=False)

# %%
#df_dropped.head()

# %%
#display the data types of the categorical variables
print(df_dropped[categorical_vars].dtypes)
# Out:
# TECH1_W99         object
# SC1_W99           object
# CNCEXC_W99        object
# ALGFAIR_W99       object
# DISCRIM1_a_W99    object
# DISCRIM1_b_W99    object
# DISCRIM1_c_W99    object
# DISCRIM1_d_W99    object
# DISCRIM1_e_W99    object
# DISCRIM1_f_W99    object
# F_AGECAT          object
# F_GENDER          object
# F_EDUCCAT2        object
# F_RACETHNMOD      object
# F_CITIZEN         object
# DCARS1_W99        object
# DCARS2_W99        object
# DCARS3_W99        object
# DCARS4_a_W99      object
# DCARS4_b_W99      object
# DCARS4_c_W99      object
# DCARS4_d_W99      object
# DCARS5_W99        object
# DCARS6_W99        object
# DCARS7_W99        object
# DCARS8_a_W99      object
# DCARS8_b_W99      object
# DCARS8_c_W99      object
# DCARS8_d_W99      object
# DCARS9_W99        object
# DCARS10_W99       object
# DCARS11_a_W99     object
# DCARS11_b_W99     object
# DCARS11_c_W99     object
# DCARS11_d_W99     object
# DCARS12_W99       object
# DCARS13_a_W99     object
# DCARS13_b_W99     object
# DCARS13_c_W99     object
# DCARS13_d_W99     object
# F_METRO           object
# F_CDIVISION       object
# F_MARITAL         object
# F_RELIGCAT1       object
# F_PARTY_FINAL     object
# F_INC_TIER2       object
# dtype: object

# %%
#df_dropped.describe()

# %%
#create a displot of tech1_w99 and the categorical vars
#visualisation of the age and tech1_w99
df_filtered = df_dropped[df_dropped['F_AGECAT'] != 'Refused']
plt.figure(figsize=(60, 30))
sns.countplot(data=df_filtered, x='F_AGECAT', hue='TECH1_W99')
plt.title("Religious Status vs TECH1_W99")
plt.show()

# %%
#visualisation of the religous status and tech1_w99
plt.figure(figsize=(60, 30))
sns.countplot(data=df_dropped, x='F_RELIGCAT1', hue='TECH1_W99')
plt.title("Religious Status vs TECH1_W99")
plt.show()

# %%
df_dropped["F_RELIGCAT1"].unique()
# Out:
# array(['Unaffiliated', 'Protestant', 'Catholic', 'Other', 'Refused'],
#       dtype=object)

# %%
# List of columns to categorize
dcars_columns = [col for col in df_filtered.columns if col.startswith('DCARS')]
# Example demographic columns
demographic_columns = ['F_AGECAT', 'F_GENDER', 'F_INC_TIER2', 'F_RELIGCAT1','F_RACETHNMOD','F_CITIZEN','F_EDUCCAT2','F_MARITAL','F_PARTY_FINAL']



# Create a summary of DCARS responses by demographic groups
summary = df_filtered.groupby(demographic_columns)[dcars_columns].agg(lambda x: x.mode()[0] if not x.mode().empty else 'Unknown')
print(summary)
# Out:
#                                                                                                                                           DCARS1_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat           Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat           Medium
#                                                                         High school graduate            Never been married Independent        Medium
#                                                                         Postgraduate                    Never been married Democrat           Medium
#                                                                         Some college, no degree         Never been married Democrat           Medium
# ...                                                                                                                                              ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent        Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent          High
#                                                                         Refused                         Married            Republican         Medium
#                                                                         Some college, no degree         Widowed            Independent          High
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else     Medium
#
#                                                                                                                                                      DCARS2_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat        Bad idea for society
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat        Bad idea for society
#                                                                         High school graduate            Never been married Independent     Bad idea for society
#                                                                         Postgraduate                    Never been married Democrat        Bad idea for society
#                                                                         Some college, no degree         Never been married Democrat        Bad idea for society
# ...                                                                                                                                                         ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent     Bad idea for society
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent     Bad idea for society
#                                                                         Refused                         Married            Republican      Bad idea for society
#                                                                         Some college, no degree         Widowed            Independent                 Not sure
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else  Bad idea for society
#
#                                                                                                                                           DCARS3_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat           Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat             High
#                                                                         High school graduate            Never been married Independent        Medium
#                                                                         Postgraduate                    Never been married Democrat           Medium
#                                                                         Some college, no degree         Never been married Democrat           Medium
# ...                                                                                                                                              ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent        Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent           Low
#                                                                         Refused                         Married            Republican         Medium
#                                                                         Some college, no degree         Widowed            Independent        Medium
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else     Medium
#
#                                                                                                                                           DCARS4_a_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat             Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat             Medium
#                                                                         High school graduate            Never been married Independent          Medium
#                                                                         Postgraduate                    Never been married Democrat             Medium
#                                                                         Some college, no degree         Never been married Democrat             Medium
# ...                                                                                                                                                ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent          Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent          Medium
#                                                                         Refused                         Married            Republican           Medium
#                                                                         Some college, no degree         Widowed            Independent             Low
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else       Medium
#
#                                                                                                                                           DCARS4_b_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat             Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat             Medium
#                                                                         High school graduate            Never been married Independent          Medium
#                                                                         Postgraduate                    Never been married Democrat             Medium
#                                                                         Some college, no degree         Never been married Democrat             Medium
# ...                                                                                                                                                ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent          Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             Low
#                                                                         Refused                         Married            Republican           Medium
#                                                                         Some college, no degree         Widowed            Independent          Medium
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else       Medium
#
#                                                                                                                                           DCARS4_c_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat             Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat               High
#                                                                         High school graduate            Never been married Independent          Medium
#                                                                         Postgraduate                    Never been married Democrat             Medium
#                                                                         Some college, no degree         Never been married Democrat                Low
# ...                                                                                                                                                ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent          Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             Low
#                                                                         Refused                         Married            Republican           Medium
#                                                                         Some college, no degree         Widowed            Independent             Low
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else       Medium
#
#                                                                                                                                           DCARS4_d_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat             Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat             Medium
#                                                                         High school graduate            Never been married Independent          Medium
#                                                                         Postgraduate                    Never been married Democrat             Medium
#                                                                         Some college, no degree         Never been married Democrat             Medium
# ...                                                                                                                                                ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent          Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent          Medium
#                                                                         Refused                         Married            Republican           Medium
#                                                                         Some college, no degree         Widowed            Independent          Medium
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else       Medium
#
#                                                                                                                                                                                   DCARS5_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                                 Not make much difference
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                                 Not make much difference
#                                                                         High school graduate            Never been married Independent                              Not make much difference
#                                                                         Postgraduate                    Never been married Democrat                                 Not make much difference
#                                                                         Some college, no degree         Never been married Democrat                                 Not make much difference
# ...                                                                                                                                                                                      ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent                              Not make much difference
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent                              Not make much difference
#                                                                         Refused                         Married            Republican                               Not make much difference
#                                                                         Some college, no degree         Widowed            Independent     Increase the gap between higher and lower-inco...
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else                           Not make much difference
#
#                                                                                                                                                                                   DCARS6_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat        Decrease the number of people killed or injure...
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat        Decrease the number of people killed or injure...
#                                                                         High school graduate            Never been married Independent     Decrease the number of people killed or injure...
#                                                                         Postgraduate                    Never been married Democrat        Decrease the number of people killed or injure...
#                                                                         Some college, no degree         Never been married Democrat        Decrease the number of people killed or injure...
# ...                                                                                                                                                                                      ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent     Decrease the number of people killed or injure...
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent     Increase the number of people killed or injure...
#                                                                         Refused                         Married            Republican      Decrease the number of people killed or injure...
#                                                                         Some college, no degree         Widowed            Independent                                               Refused
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else  Decrease the number of people killed or injure...
#
#                                                                                                                                                              DCARS7_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                            Not sure
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                            Not sure
#                                                                         High school graduate            Never been married Independent                         Not sure
#                                                                         Postgraduate                    Never been married Democrat                            Not sure
#                                                                         Some college, no degree         Never been married Democrat                            Not sure
# ...                                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent                         Not sure
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent                          Refused
#                                                                         Refused                         Married            Republican                          Not sure
#                                                                         Some college, no degree         Widowed            Independent     Those outside of the vehicle
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else                      Not sure
#
#                                                                                                                                            ...  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL   ...
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat        ...
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat        ...
#                                                                         High school graduate            Never been married Independent     ...
#                                                                         Postgraduate                    Never been married Democrat        ...
#                                                                         Some college, no degree         Never been married Democrat        ...
# ...                                                                                                                                        ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent     ...
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent     ...
#                                                                         Refused                         Married            Republican      ...
#                                                                         Some college, no degree         Widowed            Independent     ...
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else  ...
#
#                                                                                                                                                                                  DCARS10_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat        A higher standard than used for regular passen...
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat        A higher standard than used for regular passen...
#                                                                         High school graduate            Never been married Independent     A higher standard than used for regular passen...
#                                                                         Postgraduate                    Never been married Democrat        A higher standard than used for regular passen...
#                                                                         Some college, no degree         Never been married Democrat        A higher standard than used for regular passen...
# ...                                                                                                                                                                                      ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent     A higher standard than used for regular passen...
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent     A higher standard than used for regular passen...
#                                                                         Refused                         Married            Republican      A higher standard than used for regular passen...
#                                                                         Some college, no degree         Widowed            Independent     A higher standard than used for regular passen...
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else  A higher standard than used for regular passen...
#
#                                                                                                                                           DCARS11_a_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                High
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                High
#                                                                         High school graduate            Never been married Independent             High
#                                                                         Postgraduate                    Never been married Democrat                High
#                                                                         Some college, no degree         Never been married Democrat                High
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent             High
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             High
#                                                                         Refused                         Married            Republican              High
#                                                                         Some college, no degree         Widowed            Independent             High
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else          High
#
#                                                                                                                                           DCARS11_b_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                High
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                High
#                                                                         High school graduate            Never been married Independent             High
#                                                                         Postgraduate                    Never been married Democrat                High
#                                                                         Some college, no degree         Never been married Democrat                High
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent             High
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             High
#                                                                         Refused                         Married            Republican              High
#                                                                         Some college, no degree         Widowed            Independent             High
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else          High
#
#                                                                                                                                           DCARS11_c_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                High
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                High
#                                                                         High school graduate            Never been married Independent             High
#                                                                         Postgraduate                    Never been married Democrat                High
#                                                                         Some college, no degree         Never been married Democrat                High
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent             High
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             High
#                                                                         Refused                         Married            Republican              High
#                                                                         Some college, no degree         Widowed            Independent             High
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else          High
#
#                                                                                                                                           DCARS11_d_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat                High
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat                High
#                                                                         High school graduate            Never been married Independent             High
#                                                                         Postgraduate                    Never been married Democrat                High
#                                                                         Some college, no degree         Never been married Democrat                High
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent             High
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent             High
#                                                                         Refused                         Married            Republican              High
#                                                                         Some college, no degree         Widowed            Independent             High
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else          High
#
#                                                                                                                                           DCARS12_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat            Medium
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat              High
#                                                                         High school graduate            Never been married Independent         Medium
#                                                                         Postgraduate                    Never been married Democrat            Medium
#                                                                         Some college, no degree         Never been married Democrat            Medium
# ...                                                                                                                                               ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent         Medium
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent            Low
#                                                                         Refused                         Married            Republican          Medium
#                                                                         Some college, no degree         Widowed            Independent         Medium
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else      Medium
#
#                                                                                                                                           DCARS13_a_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat               Favor
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat               Favor
#                                                                         High school graduate            Never been married Independent            Favor
#                                                                         Postgraduate                    Never been married Democrat               Favor
#                                                                         Some college, no degree         Never been married Democrat               Favor
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent            Favor
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent           Oppose
#                                                                         Refused                         Married            Republican             Favor
#                                                                         Some college, no degree         Widowed            Independent         Not sure
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else         Favor
#
#                                                                                                                                           DCARS13_b_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat              Oppose
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat              Oppose
#                                                                         High school graduate            Never been married Independent           Oppose
#                                                                         Postgraduate                    Never been married Democrat              Oppose
#                                                                         Some college, no degree         Never been married Democrat              Oppose
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent           Oppose
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent           Oppose
#                                                                         Refused                         Married            Republican            Oppose
#                                                                         Some college, no degree         Widowed            Independent         Not sure
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else        Oppose
#
#                                                                                                                                           DCARS13_c_W99  \
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat              Oppose
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat               Favor
#                                                                         High school graduate            Never been married Independent           Oppose
#                                                                         Postgraduate                    Never been married Democrat              Oppose
#                                                                         Some college, no degree         Never been married Democrat              Oppose
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent           Oppose
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent           Oppose
#                                                                         Refused                         Married            Republican            Oppose
#                                                                         Some college, no degree         Widowed            Independent            Favor
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else        Oppose
#
#                                                                                                                                           DCARS13_d_W99
# F_AGECAT F_GENDER F_INC_TIER2  F_RELIGCAT1 F_RACETHNMOD       F_CITIZEN F_EDUCCAT2                      F_MARITAL          F_PARTY_FINAL
# 18-29    A man    Lower income Catholic    Asian non-Hispanic Yes       Associate's degree              Married            Democrat               Favor
#                                            Hispanic           Yes       College graduate/some post grad Never been married Democrat               Favor
#                                                                         High school graduate            Never been married Independent            Favor
#                                                                         Postgraduate                    Never been married Democrat               Favor
#                                                                         Some college, no degree         Never been married Democrat               Favor
# ...                                                                                                                                                 ...
# 65+      Refused  Refused      Protestant  Refused            Yes       College graduate/some post grad Married            Independent            Favor
#                                            White non-Hispanic Yes       College graduate/some post grad Married            Independent           Oppose
#                                                                         Refused                         Married            Republican             Favor
#                                                                         Some college, no degree         Widowed            Independent         Not sure
#                   Upper income Protestant  White non-Hispanic Yes       Postgraduate                    Married            Something else         Favor
#
# [5036 rows x 25 columns]

# %%
# List of columns to categorize
dcars_columns = [col for col in df_filtered.columns if col.startswith('DCARS')]

# Example demographic columns
demographic_columns = ['F_AGECAT', 'F_GENDER', 'F_INC_TIER2', 'F_REG', 'F_RACETHNMOD', 'F_CITIZEN', 'F_EDUCCAT2', 'F_MARITAL', 'F_PARTY_FINAL']

for col in dcars_columns:
    plt.figure(figsize=(6, 6))
    sns.countplot(data=df_filtered, x='F_AGECAT', hue=col)
    plt.title(f'Responses to {col} by Age Category')
    plt.xlabel('Age Category')
    plt.ylabel('Count')
    plt.legend(title=col)
    plt.xticks(rotation=45)
    plt.show()
#DCARS1 How much have you heard or read about driverless passenger vehicles?
#DCARS2 Do you think widespread use of driverless passenger vehicles would be a…
#DCARS3 Would you personally want to ride in a driverless passenger vehicle, if you had the opportunity?
#DCARS4 If the use of driverless passenger vehicles becomes widespread, do you think each of the following would happen? [RANDOMIZE ITEMS]
#   a. Older adults and people with disabilities will be able to live more independently
#   b. Many people who make their living by driving others or delivering things with passenger vehicles would lose their jobs
#   c. Getting from place to place would be less stressful
#   d. The computer systems in driverless
#DCARS5 If the use of driverless passenger vehicles becomes widespread, do you think that would…
#DCARS6 If the use of driverless passenger vehicles becomes widespread, do you think that would…
#DCARS7 In the case of an unavoidable accident, should the computer systems guiding driverless vehicles be designed to prioritize the safety of…
#DCARS8 How much of a role do you think each of the following groups should have in setting standards for how driverless passenger vehicles are used?
#   a. Federal government agencies
#   b The companies that develop driverless passenger vehicles
#   c. The people who use driverless passenger vehicles
#   d. The dealerships that sell driverless passenger vehicles
#DCARS9 If the use of driverless passenger vehicles becomes widespread, which is your greater concern?
#DCARS10 Which statement comes closer to your view when it comes to ensuring the safety and effectiveness of driverless passenger vehicles?
#DCARS11 Would the use of driverless passenger vehicles be more acceptable, less acceptable or would it make no difference in each of the following circumstances?
#DCARS12 If the use of driverless passenger vehicles became widespread, how comfortable would you feel sharing the road with them?
#DCARS13 The technology used to operate driverless passenger vehicles could be used for a number of purposes. Would you favor or oppose the use of this technology in each of the following purposes?
#   a. Taxis and ride-sharing vehicles
#   b. 18-wheeler trucks
#   c. Buses for public transportation
#   d. Delivery vehicles

# %%
for col in dcars_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df_filtered, x='F_AGECAT', hue=col)
    plt.title(f'Responses to {col} by Age Category')
    plt.xlabel('Age Category')
    plt.ylabel('Count')
    plt.legend(title=col)
    plt.xticks(rotation=45)
    plt.show()
#DCARS1 How much have you heard or read about driverless passenger vehicles?
#DCARS2 Do you think widespread use of driverless passenger vehicles would be a…
#DCARS3 Would you personally want to ride in a driverless passenger vehicle, if you had the opportunity?
#DCARS4 If the use of driverless passenger vehicles becomes widespread, do you think each of the following would happen? [RANDOMIZE ITEMS]
#   a. Older adults and people with disabilities will be able to live more independently
#   b. Many people who make their living by driving others or delivering things with passenger vehicles would lose their jobs
#   c. Getting from place to place would be less stressful
#   d. The computer systems in driverless
#DCARS5 If the use of driverless passenger vehicles becomes widespread, do you think that would…
#DCARS6 If the use of driverless passenger vehicles becomes widespread, do you think that would…
#DCARS7 In the case of an unavoidable accident, should the computer systems guiding driverless vehicles be designed to prioritize the safety of…
#DCARS8 How much of a role do you think each of the following groups should have in setting standards for how driverless passenger vehicles are used?
#   a. Federal government agencies
#   b The companies that develop driverless passenger vehicles
#   c. The people who use driverless passenger vehicles
#   d. The dealerships that sell driverless passenger vehicles
#DCARS9 If the use of driverless passenger vehicles becomes widespread, which is your greater concern?
#DCARS10 Which statement comes closer to your view when it comes to ensuring the safety and effectiveness of driverless passenger vehicles?
#DCARS11 Would the use of driverless passenger vehicles be more acceptable, less acceptable or would it make no difference in each of the following circumstances?
#DCARS12 If the use of driverless passenger vehicles became widespread, how comfortable would you feel sharing the road with them?
#DCARS13 The technology used to operate driverless passenger vehicles could be used for a number of purposes. Would you favor or oppose the use of this technology in each of the following purposes?
#   a. Taxis and ride-sharing vehicles
#   b. 18-wheeler trucks
#   c. Buses for public transportation
#   d. Delivery vehicles

# %%
#create a visualisation to display the distribution of the High, Medium, Low and Uncertain values in the DCARS columns
# Visualize the distribution of the DCARS columns
plt.figure(figsize=(20, 10))
for i, column in enumerate(existing_columns):
    plt.subplot(3, 5, i+1)
    sns.countplot(data=df_dropped, x=column, order=['High', 'Medium', 'Low', 'Uncertain'])
    plt.title(column)

plt.tight_layout()  
plt.show()

# %%
# Variables to plot
variables_to_plot = ['CNCEXC_W99', 'DCARS1_W99','F_AGECAT', 'F_GENDER','F_RACETHNMOD','F_EDUCCAT2']

# Plotting with slanted x-axis labels, grouped by F_PARTY_FINAL
#(Taking a look to see which political party is more likely to be accepting of self driving cars and then going further to analyse the political parties and their demographics
for var in variables_to_plot:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df_dropped, x=var, hue='F_PARTY_FINAL')
    plt.title(f'Count Plot of {var} by Party')
    plt.xlabel(var)
    plt.ylabel('Count')
    plt.legend(title='Party')
    plt.xticks(rotation=45)  # Slant the labels on the x-axis
    plt.show()
