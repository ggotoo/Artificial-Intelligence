# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey_data = pd.read_csv('/Users/georgetteotoo/Desktop/Schulich/Artificial Intelligence/Datasets/AI-Human-PewData.csv')

# %%
survey_data.head()
# Out:
#    Unnamed: 0      QKEY  INTERVIEW_START_W99    INTERVIEW_END_W99  \
# 0           0  100260.0  2021-11-03 14:25:27  2021-11-03 14:45:34
# 1           1  100314.0  2021-11-04 12:35:35  2021-11-04 12:55:29
# 2           2  100363.0  2021-11-03 20:23:43  2021-11-03 20:36:24
# 3           3  100598.0  2021-11-02 13:01:05  2021-11-04 12:37:42
# 4           4  100637.0  2021-11-02 12:32:58  2021-11-02 12:46:23
#
#   DEVICE_TYPE_W99 LANG_W99 FORM_W99    XTABLET_W99        TECH1_W99  \
# 0       Laptop/PC  English   Form 2  Non-tablet HH          Unknown
# 1      Smartphone  English   Form 1  Non-tablet HH  Mostly positive
# 2      Smartphone  English   Form 1  Non-tablet HH  Mostly positive
# 3       Laptop/PC  English   Form 2  Non-tablet HH          Unknown
# 4       Laptop/PC  English   Form 2  Non-tablet HH          Unknown
#
#                                SC1_W99  ...       F_PARTYLN_FINAL  \
# 0                      Mostly positive  ...               Unknown
# ...

# %%
categorical_columns = survey_data.select_dtypes(include=['object']).columns

# %%
survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10260 entries, 0 to 10259
# Columns: 215 entries, Unnamed: 0 to WEIGHT_W99
# dtypes: float64(2), int64(1), object(212)
# memory usage: 16.8+ MB

# %%
survey_data[categorical_columns] = survey_data[categorical_columns].fillna('Unknown')

# %%
survey_data_ohe = pd.get_dummies(survey_data, columns=categorical_columns)

# %%
survey_data_ohe.head()
# Out:
#    Unnamed: 0      QKEY  WEIGHT_W99  INTERVIEW_START_W99_2021-11-01 17:07:37  \
# 0           0  100260.0    0.206396                                    False
# 1           1  100314.0    0.315090                                    False
# 2           2  100363.0    0.829579                                    False
# 3           3  100598.0    0.337527                                    False
# 4           4  100637.0    1.210606                                    False
#
#    INTERVIEW_START_W99_2021-11-01 17:07:51  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    INTERVIEW_START_W99_2021-11-01 17:08:00  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# ...
